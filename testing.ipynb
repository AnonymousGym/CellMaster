# %% [markdown]
# ## below is testing

# %%
retina_hypothesis = (
        "You are a bioinformatics expert in single-cell RNA sequencing analysis. "
        "You have a dataset and will start from cell annotation.\n"
        "You will receive the dataset and project description from your biologist fellow. "
        "You will also receive Top Marker genes in each Cluster.\n"
        "Here is the design of our dataset and project.\n"
        "Dataset: This is a human scRNA dataset of 20 091 cells and 19 719 genes; "
        "it is a retina cell collection.\n"
        "Project Description: This published dataset is meant to test cell-type annotation "
        "capabilities. It contains retina cell types including 'Bipolar cells', "
        "'Macroglia', 'Rod', etc. You would like to include these cell types."
)
pbmc_hypothesis = """
You are a bioinformatics expert in single-cell RNA sequencing analysis. You have a dataset and will start from cell annotation.
You will receive the dataset and project description from your biologist fellow. You will also receive Top Marker genes in each Cluster.
here is design of our dataset and project.
Dataset: This is a scRNA dataset of 2638 cells and 1838 genes. it is a pbmc cell collection.
Project Description: This is an example dataset to test cell type annotation capabilities. This dataset contain pbmc cell types, including T cell, B cell, Monocyte, NK, and their subgroup like CD4 T and CD8 T, etc. You must include these cell types.
"""
OPENAI_API_KEY = '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'
import scanpy as sc 
adata = sc.read_h5ad("uploads/retina.h5ad")
# Out:
# /Users/gaoyiming/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
from cli import run_cell_annotation

adata_with_annotations = run_cell_annotation(input_adata=adata,initial_hypothesis=retina_hypothesis,output_column="version3",API_key=OPENAI_API_KEY,model_name="gpt-4o")
# Out:
# Loading Data
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# Current iteration 0
# Hypothesis Stage
# Marker gene proposal
# Dotplot Generation
# Inside evaluate
# Evaluation took 15.21 seconds
# ANNOTATION:
#  {0: 'Rod Cells', 1: 'Rod Cells', 3: 'Macroglia', 4: 'Horizontal Cells', 5: 'Bipolar Cells', 6: 'Macroglia', 7: 'Rod Cells', 8: 'Rod Cells', 9: 'Rod Cells', 10: 'Macroglia', 11: 'Macroglia', 12: 'Macroglia', 13: 'Macroglia', 14: 'Cone Photoreceptor Cells', 15: 'Rod Cells', 16: 'Macroglia', 17: 'Horizontal Cells'}
# in auto fill in
# [18, 19]
# {18: 'Bipolar cells', 19: 'Bipolar cells'}
# finish auto fill in
# UMAP plot saved as 0_CellMaster_umap_plot.png

# %%
adata_with_annotations.obs["version3"]
# Out:
# cell_id
# 0               Rod Cells
# 1               Rod Cells
# 2           Bipolar cells
# 3               Macroglia
# 4        Horizontal Cells
#                ...
# 20086           Rod Cells
# 20087           Macroglia
# 20088           Macroglia
# 20089           Rod Cells
# 20090           Rod Cells
# Name: version3, Length: 20091, dtype: category
# Categories (6, object): ['Bipolar Cells', 'Bipolar cells', 'Cone Photoreceptor Cells', 'Horizontal Cells', 'Macroglia', 'Rod Cells']
